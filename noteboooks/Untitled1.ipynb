# %%
from accelerator import *

# %%
f = 0.8  # focal length (m)
L = 1.  # drift length (m). Note FODO total length: 2L

half_quad_F = QuadrupoleThin(2.*f)
quad_D = QuadrupoleThin(-f)
drift = Drift(L)

# %%
FODO = Lattice([half_quad_F, drift, quad_D, drift, half_quad_F])

# %%
FODO.plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
half_quad_F.m @ drift.m @ quad_D.m @ drift.m @ half_quad_F.m
# Out:
# TransferMatrix([[ 0.21875   ,  3.25      ,  0.        ,  0.        ,
#                   0.        ],
#                 [-0.29296875,  0.21875   ,  0.        ,  0.        ,
#                   0.        ],
#                 [ 0.        ,  0.        ,  0.21875   ,  0.75      ,
#                   0.        ],
#                 [ 0.        ,  0.        , -1.26953125,  0.21875   ,
#                   0.        ],
#                 [ 0.        ,  0.        ,  0.        ,  0.        ,
#                   1.        ]])

# %%
FODO.m
# Out:
# TransferMatrix([[ 0.21875   ,  3.25      ,  0.        ,  0.        ,
#                   0.        ],
#                 [-0.29296875,  0.21875   ,  0.        ,  0.        ,
#                   0.        ],
#                 [ 0.        ,  0.        ,  0.21875   ,  0.75      ,
#                   0.        ],
#                 [ 0.        ,  0.        , -1.26953125,  0.21875   ,
#                   0.        ],
#                 [ 0.        ,  0.        ,  0.        ,  0.        ,
#                   1.        ]])

# %%
FODO.m[:2, :2]
# Out:
# TransferMatrix([[ 0.21875   ,  3.25      ],
#                 [-0.29296875,  0.21875   ]])

# %%
FODO.twiss()
# Out:
# TransportedTwiss(s=array([0., 0., 1., 1., 2., 2.]), beta=array([3.3306656 , 3.3306656 , 0.76861514, 0.76861514, 3.3306656 ,
#        3.3306656 ]), alpha=array([ 0.        ,  2.081666  ,  0.48038446, -0.48038446, -2.081666  ,
#         0.        ]), gamma=array([0.30024029, 1.60128154, 1.60128154, 1.60128154, 1.60128154,
#        0.30024029]))

# %%
FODO.solve_twiss()
# Out:
# array([[3.3306656 ],
#        [0.        ],
#        [0.30024029]])

# %%
FODO.twiss().plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
FODO.transport([0, 0, 0, 0, 0])
# Out:
# TransportedPhasespace(s=array([0., 0., 1., 1., 2., 2.]), x=array([0., 0., 0., 0., 0., 0.]), x_prime=array([0., 0., 0., 0., 0., 0.]), y=array([0., 0., 0., 0., 0., 0.]), y_prime=array([0., 0., 0., 0., 0., 0.]), dp=array([0., 0., 0., 0., 0., 0.]))

# %%
Beam(sigma_energy=0.1).match([1, 0, 1]).plot(plane="h")
# Out:
# (<Figure size 432x288 with 2 Axes>, <AxesSubplot:xlabel='x [m]', ylabel="x'">)

# %%
Beam(sigma_energy=0.1).ellipse([1/2, 0, 2], [1, 0, 1]).plot()
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:xlabel='x [m]', ylabel="x'">,
#         <AxesSubplot:xlabel='y [m]', ylabel="y'">], dtype=object))

# %%
Beam().match([1, 0, 1]).plot(plane="h")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='x [m]', ylabel="x'">)

# %%
FODO.plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
FODO.solve_twiss()
# Out:
# array([[3.3306656 ],
#        [0.        ],
#        [0.30024029]])

# %%
FODO.transport(Beam().ellipse(FODO.solve_twiss())).plot(plane='h')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='x [m]', ylabel="x'">)

# %%
FODO.twiss()
# Out:
# TransportedTwiss(s=array([0., 0., 1., 1., 2., 2.]), beta=array([3.3306656 , 3.3306656 , 0.76861514, 0.76861514, 3.3306656 ,
#        3.3306656 ]), alpha=array([ 0.        ,  2.081666  ,  0.48038446, -0.48038446, -2.081666  ,
#         0.        ]), gamma=array([0.30024029, 1.60128154, 1.60128154, 1.60128154, 1.60128154,
#        0.30024029]))

# %%
test = True
~test
# Out:
# -2

# %%
test
# Out:
# True

# %%
~test
# Out:
# -2

# %%
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-af72a2a08717> in <module>
# ----> 1 fig.tight_layout()
#
# NameError: name 'fig' is not defined
