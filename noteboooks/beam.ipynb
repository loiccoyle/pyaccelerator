# %%
from pyaccelerator.beam import Beam
import matplotlib.pyplot as plt
import numpy as np

# %%
beam = Beam()
beam
# Out:
# Beam(
# energy=6500000.0,
# mass=938.27208816,
# n_particles=1000,
# emittance=(3.5e-06, 3.5e-06),
# sigma_energy=0,
# sampling='bigaussian')

# %%
ellipse = beam.ellipse(twiss_h=[2,0,1/2], twiss_v=[1, 0, 1])
ellipse.plot()
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:xlabel='x [m]', ylabel="x'">,
#         <AxesSubplot:xlabel='y [m]', ylabel="y'">], dtype=object))

# %%
distrib = beam.match(twiss_h=[2,0,1/2], twiss_v=[1, 0, 1])
distrib.plot()
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:xlabel='x [m]', ylabel="x'">,
#         <AxesSubplot:xlabel='y [m]', ylabel="y'">], dtype=object))
