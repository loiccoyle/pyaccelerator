# %%
from accelerator.beam import Beam
import matplotlib.pyplot as plt
import numpy as np

# %%
beam = Beam()
beam
# Out:
# Beam(
# number=1,
# energy=6500.0,
# emittance=(3.5e-06, 3.5e-06),
# n_particles=1000.0,
# sampling='bigaussian')

# %%
u, u_prime = beam.phasespace([2,0,1/2])

# %%
plt.plot(u, u_prime)
plt.gca().set_aspect('equal')
plt.grid()
