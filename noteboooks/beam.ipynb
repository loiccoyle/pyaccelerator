# %%
from accelerator.beam import Beam
import matplotlib.pyplot as plt
import numpy as np

# %%
beam = Beam()
beam
# Out:
# Beam(
# energy=6500.0,
# mass=1.67262192369e-27,
# n_particles=1000,
# emittance=(3.5e-06, 3.5e-06),
# sampling='bigaussian')

# %%
u, u_prime = beam.ellipse([2,0,1/2])

# %%
plt.plot(u, u_prime)
plt.gca().set_aspect('equal')
plt.grid()
