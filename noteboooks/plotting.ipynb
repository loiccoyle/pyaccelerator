# %%
from accelerator import Lattice
from accelerator import Dipole, QuadrupoleThin, Drift

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = 0.8  # focal length (m)
L = 1.  # drift length (m). Note FODO total length: 2L

half_quad_F = QuadrupoleThin(2.*f)
quad_D = QuadrupoleThin(-f)
drift = Drift(1)

# %%
FODO = Lattice([half_quad_F, drift, quad_D, drift, half_quad_F, Dipole(1, np.pi/2)])

# %%
fig, ax = FODO.plot.lattice()

# %%
fig, ax = FODO.plot.top_down()

# %%
FODO = Lattice([half_quad_F, drift, quad_D, drift, half_quad_F])

# %%
FODO.transport()
# Out:
# TransportedTwiss(s=array([0, 0, 1, 1, 2, 2]), beta=array([3.3306656 , 3.3306656 , 0.76861514, 0.76861514, 3.3306656 ,
#        3.3306656 ]), alpha=array([ 0.        ,  2.081666  ,  0.48038446, -0.48038446, -2.081666  ,
#         0.        ]), gamma=array([0.30024029, 1.60128154, 1.60128154, 1.60128154, 1.60128154,
#        0.30024029]))

# %%
FODO.transport().plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
FODO.transport(phasespace=[0, 1, 0]).plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)
