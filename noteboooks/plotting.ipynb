# %%
from accelerator import *

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # lattice plotting

# %%
f = 0.8  # focal length (m)
L = 1.  # drift length (m). Note FODO total length: 2L

half_quad_F = QuadrupoleThin(2.*f)
quad_D = QuadrupoleThin(-f)
drift = Drift(1)

# %%
FODO = Lattice([half_quad_F, drift, quad_D, drift, half_quad_F, Dipole(1, np.pi/2)])

# %%
FODO.plot.lattice()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
FODO.plot.top_down()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>)

# %% [markdown]
# # Transport plotting

# %%
FODO = Lattice([half_quad_F, drift, quad_D, drift, half_quad_F])

# %%
twiss = FODO.transport()
twiss.plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
coords = FODO.transport(phasespace=[0, 1, 0])
coords.plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
ellipse = Beam().ellipse([2, 0, 1/2])
ellipse.plot()
transported_ellipse = FODO.transport(phasespace=ellipse)
transported_ellipse.plot()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='u [m]', ylabel="u' [rad]">)

# %%
distribution = Beam().match([2, 0, 1/2])
distribution.plot()
transported_distribution = FODO.transport(phasespace=distribution)
transported_distribution.plot()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='u [m]', ylabel="u' [rad]">)
