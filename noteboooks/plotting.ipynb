# %%
from pyaccelerator import *

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # lattice plotting

# %%
f = 0.8  # focal length (m)
L = 1.  # drift length (m). Note FODO total length: 2L

half_quad_F = QuadrupoleThin(2.*f)
quad_D = QuadrupoleThin(-f)
drift = Drift(1)

# %%
FODO = Lattice([half_quad_F, drift, quad_D, drift, half_quad_F, Dipole(1, np.pi/2)])

# %%
FODO.plot.layout()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
FODO.plot.top_down()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>)

# %% [markdown]
# # Transport plotting

# %%
FODO = Lattice([half_quad_F, drift, quad_D, drift, half_quad_F])

# %%
twiss = FODO.twiss()
twiss.plot()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='s [m]'>)

# %%
coords = FODO.transport([0, 1, 0, 0, 0])
coords.plot()
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([<AxesSubplot:xlabel='s [m]', ylabel='x [m]'>,
#         <AxesSubplot:xlabel='s [m]', ylabel='y [m]'>], dtype=object))

# %%
ellipse = Beam().ellipse([2, 0, 1/2])
ellipse.plot()
ellipse.plot('h')
ellipse.plot('v')
transported_ellipse = FODO.transport(ellipse)
transported_ellipse.plot()
transported_ellipse.plot('h')
transported_ellipse.plot('v')
transported_ellipse.plot(style='s')
transported_ellipse.plot(plane='h', style='s')
transported_ellipse.plot(plane='v', style='s')
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <AxesSubplot:xlabel='s [m]', ylabel='y [m]'>)

# %%
distribution = Beam(sigma_energy=1e-7).match([2, 0, 1/2])
distribution.plot()
distribution.plot('h')
distribution.plot('v')
transported_distribution = FODO.transport(distribution)
transported_distribution.plot()
transported_distribution.plot('h')
transported_distribution.plot('v')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='y [m]', ylabel="y'">)

# %%
FODO.transport([1, 0, 0, 0, 0]).plot(style='phasespace', plane='v')
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='y [m]', ylabel="y'">)
