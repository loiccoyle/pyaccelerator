# %%
from accelerator.elements import Drift
from accelerator.elements import QuadrupoleThin
from accelerator import Lattice
from accelerator.utils import to_twiss, to_v_vec, to_phase_coord

import numpy as np

# %%
to_v_vec([1,2,3,4])
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
to_phase_coord([1,2, 1])
# Out:
# array([[1],
#        [2],
#        [1]])

# %%
to_twiss([1,0,1])
# Out:
# array([[1],
#        [0],
#        [1]])

# %%
to_twiss([1, 0 , None])
# Out:
# array([[1.],
#        [0.],
#        [1.]])

# %%
to_twiss(np.array([1,0,1]))
# Out:
# array([[1],
#        [0],
#        [1]])

# %%
drift = Drift(10)
quad_f = QuadrupoleThin(1)
quad_d = QuadrupoleThin(-1)

# %%
quad_f.m_h
# Out:
# TransferMatrix([[ 1.,  0.,  0.],
#                 [-1.,  1.,  0.],
#                 [ 0.,  0.,  1.]])

# %%
drift.m_h
# Out:
# TransferMatrix([[ 1., 10.,  0.],
#                 [ 0.,  1.,  0.],
#                 [ 0.,  0.,  1.]])

# %%
Lattice([quad_d, drift, quad_f]).m_h
# Out:
# TransferMatrix([[ 11.,  10.,   0.],
#                 [-10.,  -9.,   0.],
#                 [  0.,   0.,   1.]])
