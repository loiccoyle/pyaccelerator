# %%
from accelerator.elements import Drift
import matplotlib.pyplot as plt

# %%
drift = Drift(2)
drift
# Out:
# Drift(l=2, name='drift_0')

# %%
drift.m_h
# Out:
# TransferMatrix([[1., 2., 0.],
#                 [0., 1., 0.],
#                 [0., 0., 1.]])

# %%
drift.m_h.twiss
# Out:
# TwissTransferMatrix([[ 1., -4.,  4.],
#                      [-0.,  1., -2.],
#                      [ 0., -0.,  1.]])

# %%
out = drift.plot()

# %%
type(out[1])
# Out:
# numpy.ndarray

# %% [markdown]
# # Effect of drift on the phasespace

# %%
from accelerator import Lattice
from accelerator import Beam

# %%
lattice = Lattice([Drift(1)])
lattice
# Out:
# Lattice([Drift(l=1, name='drift_1')])

# %%
s, u, u_prime, dp = lattice.transport(phasespace=Beam(emittance=1).ellipse([1, 0, 1]))

# %%
plt.figure(figsize=(12,12))
plt.plot(u, u_prime)
plt.gca().set_aspect('equal')

# %%
lat = Lattice([Drift(1)])
lat.plot.top_down()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>)
