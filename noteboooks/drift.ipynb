# %%
from accelerator.elements import Drift
import matplotlib.pyplot as plt

# %%
drift = Drift(2)

# %%
drift.m_h
# Out:
# TransferMatrix([[1., 2.],
#                 [0., 1.]])

# %%
drift.m_h.twiss
# Out:
# TwissTransferMatrix([[ 1., -4.,  4.],
#                      [-0.,  1., -2.],
#                      [ 0., -0.,  1.]])

# %%
out = drift.plot()

# %%
type(out[1])
# Out:
# numpy.ndarray

# %% [markdown]
# # Effect of drift on the phasespace

# %%
from accelerator import Lattice
from accelerator import Beam

# %%
lattice = Lattice([Drift(1)])
lattice
# Out:
# [Drift(length=1)]

# %%
u, u_prime, twiss, s = lattice.transport_beam([1,0,1], Beam(emittance=1))

# %%
plt.figure(figsize=(12,12))
plt.plot(u, u_prime)
plt.gca().set_aspect('equal')

# %%
import numpy as np

lat = Lattice([Drift(1)])
lat.plot(xztheta_init=[0,0,np.pi/4])
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>)

# %%
Drift(1).slice(10)
# Out:
# [Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1)]

# %%
Drift(1).slice(10).__str__()
# Out:
# '[Drift(length=0.1), Drift(length=0.1), Drift(length=0.1), Drift(length=0.1), Drift(length=0.1), Drift(length=0.1), Drift(length=0.1), Drift(length=0.1), Drift(length=0.1), Drift(length=0.1)]'

# %%
Drift(1).slice(10)
# Out:
# [Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1),
#  Drift(length=0.1)]
